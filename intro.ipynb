# %%
import pandas as pd

# %%
a={"id":[11,12,13],"name":["angha","rejoice","anuraj"],"age":[20,18,24]}
print(a)
# Out:
# {'id': [11, 12, 13], 'name': ['angha', 'rejoice', 'anuraj'], 'age': [20, 18, 24]}

# %%
b=pd.DataFrame(a)
(b)
# Out:
#    id     name  age
# 0  11    angha   20
# 1  12  rejoice   18
# 2  13   anuraj   24

# %%
c=[("christin",11,23),("anuraj",12,26),("malin",13,24)]
print(c)
# Out:
# [('christin', 11, 23), ('anuraj', 12, 26), ('malin', 13, 24)]

# %%
d=pd.DataFrame(c,columns=["name","id","age"])
d
# Out:
#        name  id  age
# 0  christin  11   23
# 1    anuraj  12   26
# 2     malin  13   24

# %%
import os
print(os.getcwd())
# Out:
# /Users/christinmendez/python libraries/pandas

# %%
data=pd.read_csv(r"/Users/christinmendez/python libraries/pandas/cardata.csv")
print(data)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
print(data.size)
# Out:
# 2709

# %%
print(data.shape)
# Out:
# (301, 9)

# %%
print(data.head(2))
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
print(data.tail(3))
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
print(data.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
data["Car_Name"]
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
data[["Car_Name","Fuel_Type"]]
# Out:
#     Car_Name Fuel_Type
# 0       ritz    Petrol
# 1        sx4    Diesel
# 2       ciaz    Petrol
# 3    wagon r    Petrol
# 4      swift    Diesel
# ..       ...       ...
# 296     city    Diesel
# 297     brio    Petrol
# 298     city    Petrol
# 299     city    Diesel
# 300     brio    Petrol
#
# [301 rows x 2 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=301, step=1)

# %%
data.set_index("Year")
# Out:
#      Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59       27000    Petrol      Dealer
# 2013      sx4           4.75           9.54       43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85        6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15        5200    Petrol      Dealer
# 2014    swift           4.60           6.87       42450    Diesel      Dealer
# ...       ...            ...            ...         ...       ...         ...
# 2016     city           9.50          11.60       33988    Diesel      Dealer
# 2015     brio           4.00           5.90       60000    Petrol      Dealer
# 2009     city           3.35          11.00       87934    Petrol      Dealer
# 2017     city          11.50          12.50        9000    Diesel      Dealer
# 2016     brio           5.30           5.90        5464    Petrol      Dealer
#
#      Transmission  Owner
# ...

# %%
data.reset_index()
# Out:
#      index Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0        0     ritz  2014           3.35           5.59       27000    Petrol
# 1        1      sx4  2013           4.75           9.54       43000    Diesel
# 2        2     ciaz  2017           7.25           9.85        6900    Petrol
# 3        3  wagon r  2011           2.85           4.15        5200    Petrol
# 4        4    swift  2014           4.60           6.87       42450    Diesel
# ..     ...      ...   ...            ...            ...         ...       ...
# 296    296     city  2016           9.50          11.60       33988    Diesel
# 297    297     brio  2015           4.00           5.90       60000    Petrol
# 298    298     city  2009           3.35          11.00       87934    Petrol
# 299    299     city  2017          11.50          12.50        9000    Diesel
# 300    300     brio  2016           5.30           5.90        5464    Petrol
#
# ...

# %%
data[3:5]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data[["Car_Name","Year"]][3:4]
# Out:
#   Car_Name  Year
# 3  wagon r  2011

# %%
data["Present_Price"].max()
# Out:
# 92.6

# %%
data["Present_Price"].min()
# Out:
# 0.32

# %%
data["Present_Price"].mean()
# Out:
# 7.628471760797343

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.Present_Price.std()
# Out:
# 8.644115402015784

# %%
data[data.Present_Price>11]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 45            ciaz  2014           7.50          12.04       15000    Petrol
# 50        fortuner  2012          14.90          30.61      104707    Diesel
# 51        fortuner  2015          23.00          30.61       40000    Diesel
# 52          innova  2017          18.00          19.77       15000    Diesel
# 53        fortuner  2013          16.00          30.61      135000    Diesel
# 55   corolla altis  2009           3.60          15.04       70000    Petrol
# 57   corolla altis  2010           4.75          18.54       50000    Petrol
# 59        fortuner  2014          19.99          35.96       41000    Diesel
# 60   corolla altis  2013           6.95          18.61       40001    Petrol
# 62        fortuner  2014          18.75          35.96       78000    Diesel
# 63        fortuner  2015          23.50          35.96       47000    Diesel
# ...

# %%
data[data.Selling_Price>19]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 51      fortuner  2015          23.00          30.61       40000    Diesel
# 59      fortuner  2014          19.99          35.96       41000    Diesel
# 63      fortuner  2015          23.50          35.96       47000    Diesel
# 64      fortuner  2017          33.00          36.23        6000    Diesel
# 66        innova  2017          19.75          23.15       11000    Petrol
# 82        innova  2017          23.00          25.39       15000    Diesel
# 86  land cruiser  2010          35.00          92.60       78000    Diesel
# 93      fortuner  2015          23.00          30.61       40000    Diesel
# 96        innova  2016          20.75          25.39       29000    Diesel
#
#    Seller_Type Transmission  Owner
# 51      Dealer    Automatic      0
# 59      Dealer    Automatic      0
# 63      Dealer    Automatic      0
# 64      Dealer    Automatic      0
# 66      Dealer    Automatic      0
# ...

# %%
(b)
# Out:
#    id     name  age
# 0  11    angha   20
# 1  12  rejoice   18
# 2  13   anuraj   24

# %%
b["salary"]=[20000,30000,50000]
(b)
# Out:
#    id     name  age  salary
# 0  11    angha   20   20000
# 1  12  rejoice   18   30000
# 2  13   anuraj   24   50000

# %%
b=b.drop(columns=["age"])
(b)
# Out:
#    id     name  salary
# 0  11    angha   20000
# 1  12  rejoice   30000
# 2  13   anuraj   50000

# %%
b=b.drop(index=1)
(b)
# Out:
#    id    name  salary
# 0  11   angha   20000
# 2  13  anuraj   50000

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df=sns.load_dataset("iris")
(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(df.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.drop(["species"],axis=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
yt=sns.load_dataset("penguins")
(yt)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
print(yt.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
print(yt.tail())
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
yt.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
yt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
yt.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
yt.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
yt[yt.bill_length_mm>46]
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Chinstrap   Dream            46.5           17.9              192.0
# 153  Chinstrap   Dream            50.0           19.5              196.0
# 154  Chinstrap   Dream            51.3           19.2              193.0
# 156  Chinstrap   Dream            52.7           19.8              197.0
# 158  Chinstrap   Dream            46.1           18.2              178.0
# ..         ...     ...             ...            ...                ...
# 337     Gentoo  Biscoe            48.8           16.2              222.0
# 338     Gentoo  Biscoe            47.2           13.7              214.0
# 340     Gentoo  Biscoe            46.8           14.3              215.0
# 341     Gentoo  Biscoe            50.4           15.7              222.0
# 343     Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 152       3500.0  Female
# 153       3900.0    Male
# ...

# %%
yt[yt.flipper_length_mm<193]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# 6       Adelie  Torgersen            38.9           17.8              181.0
# 9       Adelie  Torgersen            42.0           20.2              190.0
# ..         ...        ...             ...            ...                ...
# 198  Chinstrap      Dream            50.1           17.9              190.0
# 200  Chinstrap      Dream            51.5           18.7              187.0
# 206  Chinstrap      Dream            42.5           17.3              187.0
# 208  Chinstrap      Dream            45.2           16.6              191.0
# 213  Chinstrap      Dream            46.8           16.5              189.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
kh=yt["bill_length_mm"].mean()
print(kh)
# Out:
# 43.9219298245614

# %%
yt["bill_length_mm"]=yt["bill_length_mm"].replace(np.nan,kh)

# %%
import numpy as np

# %%
yt.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
kp=yt["bill_depth_mm"].mean()
(kp)
# Out:
# 17.151169590643278

# %%
yt["bill_depth_mm"]=yt["bill_depth_mm"].replace(np.nan,kp)

# %%
yt.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
kl=yt["flipper_length_mm"].mean()
(kl)
# Out:
# 200.91520467836258

# %%
yt["flipper_length_mm"]=yt["flipper_length_mm"].replace(np.nan,kl)

# %%
yt.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# dtype: int64

# %%
jk=yt["body_mass_g"].mean()
(jk)
# Out:
# 4201.754385964912

# %%
yt["body_mass_g"]=yt["body_mass_g"].replace(np.nan,jk)

# %%
yt.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# dtype: int64

# %%
ok=yt["sex"].mode().values[0]
(ok)
# Out:
# 'Male'

# %%
yt["sex"]=yt["sex"].replace(np.nan,ok)

# %%
yt.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
data=sns.load_dataset("penguins")
(data)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
data.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
data.size
# Out:
# 2408

# %%
data.shape
# Out:
# (344, 7)

# %%
data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...
